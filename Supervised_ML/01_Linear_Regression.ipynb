# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\MEGHARAJ1\OneDrive\cmprogram\Desktop\MachineLearning_Revise\cgpa_package_dataset.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.69     5.68
# 1  9.28     8.47
# 2  8.29     7.61
# 3  7.69     6.56
# 4  5.70     6.06

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x = "cgpa", y = "package", data = df)
plt.xlabel("Cgpa")
plt.ylabel("Package")
plt.show()

# %%
x = df[["cgpa"]]
y = df["package"]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[5.6]])
# Out:
# c:\Users\MEGHARAJ1\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.05443888])

# %%
print(f"coefficent of Dependent var is : {lr.coef_} and Intercept is {lr.intercept_}")
# Out:
# coefficent of Dependent var is : [0.91158679] and Intercept is -0.050447168091444006

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x = "cgpa", y = "package", data = df)
plt.plot(df["cgpa"], lr.predict(x), c = "red", label = "Predict Line")
plt.legend()
plt.xlabel("Cgpa")
plt.ylabel("Package")
plt.show()
