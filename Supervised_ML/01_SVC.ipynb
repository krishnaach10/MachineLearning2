# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\MEGHARAJ1\OneDrive\cmprogram\Desktop\MachineLearning_Revise\Supervised_ML\placement.csv")

# %%
dataset.head()
# Out:
#    cgpa  score  placement
# 0   6.5     60          0
# 1   7.2     72          1
# 2   8.1     85          1
# 3   5.9     55          0
# 4   9.0     92          1

# %%
sns.scatterplot(x = "cgpa", y = "score", data = dataset, hue = "placement", palette = ["blue", "green"])
plt.legend()
plt.show()

# %%
x = dataset.iloc[:,:-1]
y = dataset["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=30)

# %%
from sklearn.svm import SVC
svc = SVC(kernel= "linear")
svc.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.predict([[7.2, 72]])
# Out:
# c:\Users\MEGHARAJ1\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(), y.to_numpy(), clf = svc)
plt.show()
# Out:
# c:\Users\MEGHARAJ1\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
